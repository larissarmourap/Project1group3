# %% [markdown]
# ## Project 1 - Predictors of Pregnancy Risk

# %% [markdown]
# Our research aims to identify the key indicators that influence risk levels during pregnancy. We
# are using a dataset taken from various hospitals, clinics and maternal health cares in Bangladesh, India.
# Our primary focus is analyzing age, blood pressure, heart rate, and blood sugar to determine their impact on
# predicted risk intensity level of pregnancy complication.

# %%
import pandas as pd
from pathlib import Path
import hvplot.pandas
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
from scipy.stats import linregress, pearsonr
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="f549647d-5c32-4d0b-87e4-b32268e3ca11" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"dabe0bd0-69ae-4f4e-a3e8-e86e88a31e37":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"7c6804f16da447059e329effd1a53b19","client_comm_id":"c0f379bc51654440a336e012a43c2b7b"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"dabe0bd0-69ae-4f4e-a3e8-e86e88a31e37","roots":{"p1002":"f549647d-5c32-4d0b-87e4-b32268e3ca11"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# Create a path to CSV files, read the path and print DataFrame
file_path = (r"C:\Users\alexi\Desktop\Project1group3\maternal-health.csv")
maternal_health = pd.read_csv(file_path)
maternal_health
# Out:
#       Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0      25         130           80  15.0      98.0         86  high risk
# 1      35         140           90  13.0      98.0         70  high risk
# 2      29          90           70   8.0     100.0         80  high risk
# 3      30         140           85   7.0      98.0         70  high risk
# 4      35         120           60   6.1      98.0         76   low risk
# ...   ...         ...          ...   ...       ...        ...        ...
# 1009   22         120           60  15.0      98.0         80  high risk
# 1010   55         120           90  18.0      98.0         60  high risk
# 1011   35          85           60  19.0      98.0         86  high risk
# 1012   43         120           90  18.0      98.0         70  high risk
# 1013   32         120           65   6.0     101.0         76   mid risk
#
# [1014 rows x 7 columns]

# %%
# Count each risk level before cleaning data
risk_count = maternal_health["RiskLevel"].value_counts()
risk_count
# Out:
# RiskLevel
# low risk     406
# mid risk     336
# high risk    272
# Name: count, dtype: int64

# %%
# Clean Data: Drop all of the duplicates
maternal_clean = maternal_health.drop_duplicates(subset=None, keep='first', inplace=False)
maternal_clean
# Out:
#      Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0     25         130           80  15.0      98.0         86  high risk
# 1     35         140           90  13.0      98.0         70  high risk
# 2     29          90           70   8.0     100.0         80  high risk
# 3     30         140           85   7.0      98.0         70  high risk
# 4     35         120           60   6.1      98.0         76   low risk
# ..   ...         ...          ...   ...       ...        ...        ...
# 673   12         100           50   6.4      98.0         70   mid risk
# 674   15         100           60   6.0      98.0         80   low risk
# 703   15         100           49   7.6      98.0         77   low risk
# 704   12         100           50   6.0      98.0         70   mid risk
# 705   21         100           50   6.8      98.0         60   low risk
#
# [452 rows x 7 columns]

# %%
# Count each risk level after cleaning data
clean_count = maternal_clean["RiskLevel"].value_counts()
clean_count
# Out:
# RiskLevel
# low risk     234
# high risk    112
# mid risk     106
# Name: count, dtype: int64

# %%
# Add a new column "Woman_ID" with unique identifiers starting from 1
maternal_clean["Woman_ID"] = range(1, len(maternal_clean) + 1)

columns = ["Woman_ID"] + [col for col in maternal_clean.columns if col !="Woman_ID"]

maternal_clean = maternal_clean[columns]

maternal_clean
# Out:
#      Woman_ID  Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  \
# 0           1   25         130           80  15.0      98.0         86
# 1           2   35         140           90  13.0      98.0         70
# 2           3   29          90           70   8.0     100.0         80
# 3           4   30         140           85   7.0      98.0         70
# 4           5   35         120           60   6.1      98.0         76
# ..        ...  ...         ...          ...   ...       ...        ...
# 673       448   12         100           50   6.4      98.0         70
# 674       449   15         100           60   6.0      98.0         80
# 703       450   15         100           49   7.6      98.0         77
# 704       451   12         100           50   6.0      98.0         70
# 705       452   21         100           50   6.8      98.0         60
#
#      RiskLevel
# 0    high risk
# 1    high risk
# 2    high risk
# 3    high risk
# 4     low risk
# ..         ...
# 673   mid risk
# 674   low risk
# 703   low risk
# 704   mid risk
# 705   low risk
#
# [452 rows x 8 columns]

# %%
# Rename column names to make it easier to understand
maternal_renamed = maternal_clean.rename(columns={"Woman_ID":"Woman ID", "BS":"Blood Sugar", "SystolicBP":"Systolic Blood Pressure", 
                                                   "DiastolicBP":"Diastolic Blood Pressure", "BodyTemp":"Body Temp.", 
                                                   "HeartRate":"Heart Rate", "RiskLevel":"Risk Level"})
maternal_renamed.head()
# Out:
#    Woman ID  Age  Systolic Blood Pressure  Diastolic Blood Pressure  \
# 0         1   25                      130                        80
# 1         2   35                      140                        90
# 2         3   29                       90                        70
# 3         4   30                      140                        85
# 4         5   35                      120                        60
#
#    Blood Sugar  Body Temp.  Heart Rate Risk Level
# 0         15.0        98.0          86  high risk
# 1         13.0        98.0          70  high risk
# 2          8.0       100.0          80  high risk
# 3          7.0        98.0          70  high risk
# 4          6.1        98.0          76   low risk

# %%
# Create a new column "Blood Pressure" by combining "Systolic Blood Pressure" and "Diastolic Blood Pressure"
maternal_renamed.loc[:, 'Blood Pressure'] = maternal_renamed['Systolic Blood Pressure'].astype(str) + '/' + maternal_renamed['Diastolic Blood Pressure'].astype(str)

# Print
maternal_renamed.head()
# Out:
#    Woman ID  Age  Systolic Blood Pressure  Diastolic Blood Pressure  \
# 0         1   25                      130                        80
# 1         2   35                      140                        90
# 2         3   29                       90                        70
# 3         4   30                      140                        85
# 4         5   35                      120                        60
#
#    Blood Sugar  Body Temp.  Heart Rate Risk Level Blood Pressure
# 0         15.0        98.0          86  high risk         130/80
# 1         13.0        98.0          70  high risk         140/90
# 2          8.0       100.0          80  high risk          90/70
# 3          7.0        98.0          70  high risk         140/85
# 4          6.1        98.0          76   low risk         120/60

# %%
# Clean Data: move the "Blood Pressure" column next to Diastolic Blood Pressure to organize the DataFrame.
column_to_move = maternal_renamed.pop("Blood Pressure")
maternal_renamed.insert(4, "Blood Pressure", column_to_move)
maternal_renamed.head()
# Out:
#    Woman ID  Age  Systolic Blood Pressure  Diastolic Blood Pressure  \
# 0         1   25                      130                        80
# 1         2   35                      140                        90
# 2         3   29                       90                        70
# 3         4   30                      140                        85
# 4         5   35                      120                        60
#
#   Blood Pressure  Blood Sugar  Body Temp.  Heart Rate Risk Level
# 0         130/80         15.0        98.0          86  high risk
# 1         140/90         13.0        98.0          70  high risk
# 2          90/70          8.0       100.0          80  high risk
# 3         140/85          7.0        98.0          70  high risk
# 4         120/60          6.1        98.0          76   low risk

# %% [markdown]
# ## Blood Pressure Vs. Risk Level
# ### How much blood pressure is safe during pregnancy?

# %%
# Create a DataFrame using data from Systolic Blood Pressure, Diastolic Blood Pressure and Blood Pressure.
# A pregnant woman’s blood pressure should be within the healthy range of less than 120/80 mm Hg.
maternal_bp = maternal_renamed[["Woman ID", "Age", "Systolic Blood Pressure", "Diastolic Blood Pressure", "Blood Pressure"]].copy()
maternal_bp
# Out:
#      Woman ID  Age  Systolic Blood Pressure  Diastolic Blood Pressure  \
# 0           1   25                      130                        80
# 1           2   35                      140                        90
# 2           3   29                       90                        70
# 3           4   30                      140                        85
# 4           5   35                      120                        60
# ..        ...  ...                      ...                       ...
# 673       448   12                      100                        50
# 674       449   15                      100                        60
# 703       450   15                      100                        49
# 704       451   12                      100                        50
# 705       452   21                      100                        50
#
#     Blood Pressure
# 0           130/80
# 1           140/90
# 2            90/70
# 3           140/85
# 4           120/60
# ..             ...
# 673         100/50
# 674         100/60
# 703         100/49
# 704         100/50
# 705         100/50
#
# [452 rows x 5 columns]

# %%
# Define bins for Systolic BP
systolic_bins = [0, 119, 129, max(maternal_bp['Systolic Blood Pressure'])+1]
systolic_labels = ["Normal", "Elevated", "High"]

# Create a copy of the DataFrame to avoid modifying the original data
sys_categorized = maternal_bp.copy()

# Use `pd.cut` to categorize Systolic BP
sys_categorized['Systolic BP Category'] = pd.cut(sys_categorized['Systolic Blood Pressure'], bins=systolic_bins, labels=systolic_labels, include_lowest=True)

sys_categorized
# Out:
#      Woman ID  Age  Systolic Blood Pressure  Diastolic Blood Pressure  \
# 0           1   25                      130                        80
# 1           2   35                      140                        90
# 2           3   29                       90                        70
# 3           4   30                      140                        85
# 4           5   35                      120                        60
# ..        ...  ...                      ...                       ...
# 673       448   12                      100                        50
# 674       449   15                      100                        60
# 703       450   15                      100                        49
# 704       451   12                      100                        50
# 705       452   21                      100                        50
#
#     Blood Pressure Systolic BP Category
# 0           130/80                 High
# 1           140/90                 High
# 2            90/70               Normal
# 3           140/85                 High
# 4           120/60             Elevated
# ..             ...                  ...
# 673         100/50               Normal
# 674         100/60               Normal
# 703         100/49               Normal
# 704         100/50               Normal
# 705         100/50               Normal
#
# [452 rows x 6 columns]

# %%
# Define bins for Diastolic BP
diastolic_bins = [0, 79, 89, max(maternal_bp['Diastolic Blood Pressure'])+1]
diastolic_labels = ["Normal", "Elevated", "High"]

# Create a copy of DF above to include Systolic range
dias_categorized = sys_categorized.copy()

# Use `pd.cut` to categorize Diastolic BP
dias_categorized['Diastolic BP Category'] = pd.cut(dias_categorized['Diastolic Blood Pressure'], bins=diastolic_bins, labels=diastolic_labels, include_lowest=True)

dias_categorized
# Out:
#      Woman ID  Age  Systolic Blood Pressure  Diastolic Blood Pressure  \
# 0           1   25                      130                        80
# 1           2   35                      140                        90
# 2           3   29                       90                        70
# 3           4   30                      140                        85
# 4           5   35                      120                        60
# ..        ...  ...                      ...                       ...
# 673       448   12                      100                        50
# 674       449   15                      100                        60
# 703       450   15                      100                        49
# 704       451   12                      100                        50
# 705       452   21                      100                        50
#
#     Blood Pressure Systolic BP Category Diastolic BP Category
# 0           130/80                 High              Elevated
# 1           140/90                 High                  High
# 2            90/70               Normal                Normal
# 3           140/85                 High              Elevated
# 4           120/60             Elevated                Normal
# ..             ...                  ...                   ...
# 673         100/50               Normal                Normal
# 674         100/60               Normal                Normal
# 703         100/49               Normal                Normal
# 704         100/50               Normal                Normal
# 705         100/50               Normal                Normal
#
# [452 rows x 7 columns]

# %% [markdown]
# # Hypothesis:
# ### Women who have a high blood pressure are at a higher risk than women who are within the normal blood pressure range.

# %%
from scipy import stats

# %%
# Generate a line plot for BP
grouped_bp = maternal_bp.groupby('Age')[['Systolic Blood Pressure', 'Diastolic Blood Pressure']].mean()

# Plotting data
plt.figure(figsize=(7, 5))
plt.plot(grouped_bp['Systolic Blood Pressure'], linestyle='-', color='steelblue', label='Systolic BP')
plt.plot(grouped_bp['Diastolic Blood Pressure'], linestyle='-', color='red', label='Diastolic BP')

# Labeling 
plt.xlabel('Age', fontsize=14)
plt.ylabel('Blood Pressure (mmHg)', fontsize=14)
plt.title('Blood Pressure by Age', fontsize=16)
plt.legend()

# Print and save graph as .png
plt.savefig("C:/Users/alexi/Desktop/Project1group3/Fig1.png")
plt.show()

# %%
# Creating a pie chart distributing blood pressure categories
def categorize_bp(row):
    if row['Systolic Blood Pressure'] < 120 and row['Diastolic Blood Pressure'] < 80:
        return 'Normal'
    elif (120 <= row['Systolic Blood Pressure'] < 130) or (80 <= row['Diastolic Blood Pressure'] < 89):
        return 'Elevated'
    else:
        return 'High'

maternal_bp['BP_Category'] = maternal_bp.apply(categorize_bp, axis=1)
category_counts = maternal_bp['BP_Category'].value_counts()

# Ploting pie chart
plt.figure(figsize=(8, 8))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140, colors=['orange', 'green', 'red'])
plt.title('Distribution of Blood Pressure Categories')

# Print and save graph as .png
plt.savefig("C:/Users/alexi/Desktop/Project1group3/Fig2.png")
plt.show()

# %%
# Generate the t-test to determine if there is a significant correlation.

stats.ttest_ind(grouped_bp["Systolic Blood Pressure"], grouped_bp["Diastolic Blood Pressure"], equal_var=False)
# Out:
# TtestResult(statistic=13.862827762089772, pvalue=6.36572839949892e-24, df=88.71723614506628)

# %% [markdown]
# <span style="color:green"> The result of the pvalue was "0.00000000000000000000000636572839949892", therefore it is significant. </span>

# %% [markdown]
# ## Blood Sugar Vs. Risk Level
# ### How do Blood glucose levels (mmol/L) affect the risk level during pregnancy?

# %%
# Create a DataFrame using data from the Age and Blood Sugar.
# The normal blood sugar should be within the healthy range of less than 7.8 mmol/L.
maternal_bs = maternal_renamed[["Woman ID", "Age", "Blood Sugar"]].copy()
maternal_bs
# Out:
#      Woman ID  Age  Blood Sugar
# 0           1   25         15.0
# 1           2   35         13.0
# 2           3   29          8.0
# 3           4   30          7.0
# 4           5   35          6.1
# ..        ...  ...          ...
# 673       448   12          6.4
# 674       449   15          6.0
# 703       450   15          7.6
# 704       451   12          6.0
# 705       452   21          6.8
#
# [452 rows x 3 columns]

# %%
# Define bins for Blood Sugar
bs_bins = [0, 6, 12, max(maternal_bs['Blood Sugar'])+1]
bs_labels = ["Low Risk", "Mid Risk", "High Risk"]

# Create a copy of DataFrame above
bs_categorized = maternal_bs.copy()

# Use `pd.cut` to categorize Blood Sugar
bs_categorized['Risk Level by Blood Sugar'] = pd.cut(bs_categorized['Blood Sugar'], bins=bs_bins, labels=bs_labels, include_lowest=True)

bs_categorized
# Out:
#      Woman ID  Age  Blood Sugar Risk Level by Blood Sugar
# 0           1   25         15.0                 High Risk
# 1           2   35         13.0                 High Risk
# 2           3   29          8.0                  Mid Risk
# 3           4   30          7.0                  Mid Risk
# 4           5   35          6.1                  Mid Risk
# ..        ...  ...          ...                       ...
# 673       448   12          6.4                  Mid Risk
# 674       449   15          6.0                  Low Risk
# 703       450   15          7.6                  Mid Risk
# 704       451   12          6.0                  Low Risk
# 705       452   21          6.8                  Mid Risk
#
# [452 rows x 4 columns]

# %%
# Defining Bins for Age
age_bins = [0, 20, 30, 40, 50, max(bs_categorized['Age'])+1]
age_labels = ['<20', '20-30', '31-40', '41-50', '>50']

bs_categorized['Age Group'] = pd.cut(bs_categorized['Age'], bins=age_bins, labels=age_labels, right=False)

bs_categorized.head()
# Out:
#    Woman ID  Age  Blood Sugar Risk Level by Blood Sugar Age Group
# 0         1   25         15.0                 High Risk     20-30
# 1         2   35         13.0                 High Risk     31-40
# 2         3   29          8.0                  Mid Risk     20-30
# 3         4   30          7.0                  Mid Risk     31-40
# 4         5   35          6.1                  Mid Risk     31-40

# %%
# Import warnings to avoid "Pandas Future Error" warning 
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Generate a bar graph for Blood Sugar
bloodsugar = bs_categorized.groupby(['Age Group', 'Risk Level by Blood Sugar'])['Blood Sugar'].mean().reset_index()

# Pivotting data to include each column
pivot_bs = bloodsugar.pivot(index='Age Group', columns='Risk Level by Blood Sugar', values='Blood Sugar')

# Plotting data
pivot_bs.plot(kind='bar', figsize=(6, 5), color=["g", "orange", "r"])
plt.xlabel('Age', fontsize=14)
plt.ylabel('Blood Sugar', fontsize=14)
plt.title('Blood Sugar by Age and Risk Level', fontsize=16)
plt.legend(title='Risk Level')
plt.xticks(rotation=360)

# Print and save graph as .png
plt.savefig("C:/Users/alexi/Desktop/Project1group3/Fig3.png")
plt.show()

# %%
# Generate a Scatter Plot for Blood Sugar
from scipy.stats import linregress

# Plotting scatter plot
plt.figure(figsize=(10, 6))


# Linear Regression plotting
x_values = bs_categorized["Age"]
y_values = bs_categorized["Blood Sugar"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq, (55,9.5), fontsize=15, color = "red")

# Labeling
plt.title('Blood Sugar vs. Age')
plt.xlabel('Age')
plt.ylabel('Blood Sugar')


# Print and save graph as .png
plt.savefig("C:/Users/alexi/Desktop/Project1group3/Fig4.png")
plt.show()

# %% [markdown]
# ## Age Vs. Risk Level

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, on Risk Level based on Age
summary =  maternal_renamed.groupby(['Risk Level'])[['Age']].agg(['mean', 'median', 'var', 'std', 'sem']).reset_index()

summary.columns = ['Risk Level', 'Mean', 'Median', 'Variance', 'Std. Dev.', 'SEM']

summary.round()
# Out:
#   Risk Level  Mean  Median  Variance  Std. Dev.  SEM
# 0  high risk  34.0    34.0     184.0       14.0  1.0
# 1   low risk  27.0    22.0     193.0       14.0  1.0
# 2   mid risk  29.0    26.0     162.0       13.0  1.0

# %%
# Found the Quartiles, Outliers
risk_levels = maternal_renamed['Risk Level'].unique()

# Initialize an empty list to hold age data for each risk level
age_boxplot = []
for risk_level in risk_levels:
    print(f"------------------------------------------------------------------------")
    print(f"Risk Level: {risk_level}")

    # Locate 'Age' values for the current 'Risk Level'
    ages = maternal_renamed[maternal_renamed['Risk Level'] == risk_level]['Age']

     # add subset 
    age_boxplot.append(ages)
    
    quartiles = ages.quantile([.25, .5, .75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq - lowerq
    lower_bound = lowerq - (1.5 * iqr)
    upper_bound = upperq + (1.5 * iqr)
    
    print(f"The upper quartile of age is: {upperq}")
    print(f"The lower quartile of age is: {lowerq}")
    print(f"The interquartile range of age is: {iqr}")
    print(f"Values below {lower_bound} could be outliers for risk level {risk_level}.")
    print(f"Values above {upper_bound} could be outliers for risk level {risk_level}.")
    print(f"------------------------------------------------------------------------")
# Out:
# ------------------------------------------------------------------------
# Risk Level: high risk
# The upper quartile of age is: 42.0
# The lower quartile of age is: 25.0
# The interquartile range of age is: 17.0
# Values below -0.5 could be outliers for risk level high risk.
# Values above 67.5 could be outliers for risk level high risk.
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Risk Level: low risk
# The upper quartile of age is: 33.5
# The lower quartile of age is: 18.0
# The interquartile range of age is: 15.5
# Values below -5.25 could be outliers for risk level low risk.
# Values above 56.75 could be outliers for risk level low risk.
# ------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Risk Level: mid risk
# The upper quartile of age is: 32.0
# The lower quartile of age is: 19.0
# The interquartile range of age is: 13.0
# Values below -0.5 could be outliers for risk level mid risk.
# Values above 51.5 could be outliers for risk level mid risk.
# ------------------------------------------------------------------------

# %%
# Generate a boxplot

fig1, ax1 = plt.subplots()
ax1.set_title('Risk Level based on Age')
ax1.set_ylabel('Age')

# Set the locations for the x-ticks
ax1.set_xticks([1, 2, 3])

# Now, set the labels for each tick
label_risk_level = ["Low Risk", "Mid Risk", "High Risk"]
ax1.set_xticklabels(label_risk_level)

custom_color = dict(markerfacecolor="red", markersize=14)
ax1.boxplot(age_boxplot, labels=label_risk_level, flierprops=custom_color)

# Print and save graph as .png
plt.savefig("C:/Users/alexi/Desktop/Project1group3/Fig5.png")
plt.show()

# %% [markdown]
# # Heart Rate Vs. Risk Level
# ## Hypothesis:
# The resting heart rate of a woman during pregnancy correlates with the risk level of the pregnancy. Certain heart rates could suggest whether her pregnancy is at a higher or lower risk.

# %%
maternal_hr = maternal_renamed[['Woman ID', "Heart Rate"]].copy()
maternal_hr.head()
# Out:
#    Woman ID  Heart Rate
# 0         1          86
# 1         2          70
# 2         3          80
# 3         4          70
# 4         5          76

# %%
# Defining Bins for Heart Rate
hr_bins = [50, 60, 70, 90, 110]
hr_labels = ['Low', 'Normal', 'Elevated', 'High']

# Create a copy of DF above to include Heart Rate
hr_categorized = maternal_hr.copy()

# Use `pd.cut` to categorize Heart Rate
hr_categorized['Heart Rate Category'] = pd.cut(hr_categorized['Heart Rate'], bins=hr_bins, labels=hr_labels, include_lowest=True)

hr_categorized.head()
# Out:
#    Woman ID  Heart Rate Heart Rate Category
# 0         1          86            Elevated
# 1         2          70              Normal
# 2         3          80            Elevated
# 3         4          70              Normal
# 4         5          76            Elevated

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
hr = hr_categorized.groupby("Heart Rate Category")[["Heart Rate"]].count()
plot_pandas = hr.plot.bar(figsize=(5,5), color='r',fontsize = 14)
plt.xlabel("Risk Level",fontsize = 14)
plt.ylabel("Heart Rate",fontsize = 14)
plt.title("Risk Level based on Heart Rates",fontsize = 20)

# Print and save graph as .png
plt.savefig("C:/Users/alexi/Desktop/Project1group3/Fig6.png")
plt.show()

# %% [markdown]
# ## Geoapify
# ### Hospitals in Bangladesh, India
# We are using a dataset taken from various hospitals, clinics and maternal health cares in Bangladesh, India.

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import json
import warnings
warnings.filterwarnings("ignore")
# Import API key
from api_keys import geoapify_key

# %%
# Create the target city and endpoint url
target_city = "Bangladesh, India"
target_url = f"https://api.geoapify.com/v1/geocode/search?text={target_city}&format=json&apiKey={geoapify_key}"

# %%
# Run a request to endpoint and convert result to json
geo_data = requests.get(target_url).json()
print(geo_data)
# Out:
# {'results': [{'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'name': 'Bangladesh Colony', 'ref': '160A', 'country': 'India', 'country_code': 'in', 'state': 'Kerala', 'state_district': 'Thiruvananthapuram District', 'county': 'Thiruvananthapuram', 'city': 'Thiruvananthapuram', 'postcode': '695001', 'district': 'V.V.Krishna Menon Nagar', 'suburb': 'Thiruvallam', 'street': 'Thiruvananthapuram Bypass', 'lon': 76.9304395, 'lat': 8.466881, 'state_code': 'KL', 'result_type': 'amenity', 'formatted': 'Bangladesh Colony, Thiruvananthapuram Bypass, Thiruvallam, Thiruvananthapuram - 695001, KL, India', 'address_line1': 'Bangladesh Colony', 'address_line2': 'Thiruvananthapuram Bypass, Thiruvallam, Thiruvananthapuram - 695001, KL, India', 'category': 'public_transport.bus', 'timezone': {'name': 'Asia/Kolkata', 'offset_STD': '+05:30', 'offset_STD_seconds': 19800, 'offset_DST': '+05:30', 'offset_DST_seconds': 19800, 'abbreviation_STD': 'IST', 'abbreviation_DST': 'IST'}, 'plus_code': '6JWRFW8J+Q5', 'plus_code_short': 'FW8J+Q5 Thiruvananthapuram, India', 'rank': {'importance': 9.99999999995449e-06, 'popularity': 1.2268790831584977, 'confidence': 0.9, 'confidence_city_level': 0.9, 'match_type': 'inner_part'}, 'place_id': '5106da1d528c3b534059603fc4060bef2040f00103f9010a76e39702000000c0020192031142616e676c616465736820436f6c6f6e79e203246f70656e7374726565746d61703a76656e75653a6e6f64652f3131313338323031303938', 'bbox': {'lon1': 76.9303895, 'lat1': 8.466831, 'lon2': 76.9304895, 'lat2': 8.466931}}, {'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'name': 'Viewpoint to Bangladesh', 'country': 'India', 'country_code': 'in', 'state': 'Meghalaya', 'state_district': 'East Khasi Hills District', 'county': 'Shella Bholaganj', 'postcode': '793107', 'street': 'FOOTHPATH', 'lon': 91.7283976, 'lat': 25.2244319, 'state_code': 'ML', 'result_type': 'amenity', 'formatted': 'Viewpoint to Bangladesh, FOOTHPATH, - 793107, ML, India', 'address_line1': 'Viewpoint to Bangladesh', 'address_line2': 'FOOTHPATH, - 793107, ML, India', 'category': 'tourism.attraction.viewpoint', 'timezone': {'name': 'Asia/Kolkata', 'offset_STD': '+05:30', 'offset_STD_seconds': 19800, 'offset_DST': '+05:30', 'offset_DST_seconds': 19800, 'abbreviation_STD': 'IST', 'abbreviation_DST': 'IST'}, 'plus_code': '7MQH6PFH+Q9', 'rank': {'importance': 9.99999999995449e-06, 'popularity': 0.45710529876246103, 'confidence': 0.81, 'confidence_city_level': 0.81, 'match_type': 'inner_part'}, 'place_id': '51089ff7109eee564059dcad765e74393940f00103f90115038fac01000000c0020192031756696577706f696e7420746f2042616e676c6164657368e203236f70656e7374726565746d61703a76656e75653a6e6f64652f37313930303230383835', 'bbox': {'lon1': 91.7283476, 'lat1': 25.2243819, 'lon2': 91.7284476, 'lat2': 25.2244819}}, {'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'name': 'Bangladesh Plains Viewpoint', 'country': 'India', 'country_code': 'in', 'state': 'Meghalaya', 'state_district': 'East Khasi Hills District', 'county': 'Shella Bholaganj', 'city': 'Sohkhmi', 'postcode': '793110', 'street': 'Sokhmi / Wah Lyngngam (The Green River) Trekking Route', 'lon': 91.7559202, 'lat': 25.2474361, 'state_code': 'ML', 'result_type': 'amenity', 'formatted': 'Bangladesh Plains Viewpoint, Sokhmi / Wah Lyngngam (The Green River) Trekking Route, Sohkhmi - 793110, ML, India', 'address_line1': 'Bangladesh Plains Viewpoint', 'address_line2': 'Sokhmi / Wah Lyngngam (The Green River) Trekking Route, Sohkhmi - 793110, ML, India', 'category': 'tourism.attraction.viewpoint', 'timezone': {'name': 'Asia/Kolkata', 'offset_STD': '+05:30', 'offset_STD_seconds': 19800, 'offset_DST': ...

# %%
# Print the json (pretty printed)
print(json.dumps(geo_data, indent=4, sort_keys=True))
# Out:
# {
#     "query": {
#         "parsed": {
#             "city": "bangladesh",
#             "country": "india",
#             "expected_type": "city"
#         },
#         "text": "Bangladesh, India"
#     },
#     "results": [
#         {
#             "address_line1": "Bangladesh Colony",
#             "address_line2": "Thiruvananthapuram Bypass, Thiruvallam, Thiruvananthapuram - 695001, KL, India",
#             "bbox": {
#                 "lat1": 8.466831,
#                 "lat2": 8.466931,
#                 "lon1": 76.9303895,
#                 "lon2": 76.9304895
#             },
#             "category": "public_transport.bus",
#             "city": "Thiruvananthapuram",
#             "country": "India",
#             "country_code": "in",
#             "county": "Thiruvananthapuram",
#             "datasource": {
#                 "attribution": "\u00a9 OpenStreetMap contributors",
#                 "license": "Open Database License",
#                 "sourcename": "openstreetmap",
#                 "url": "https://www.openstreetmap.org/copyright"
#             },
#             "district": "V.V.Krishna Menon Nagar",
#             "formatted": "Bangladesh Colony, Thiruvananthapuram Bypass, Thiruvallam, Thiruvananthapuram - 695001, KL, India",
#             "lat": 8.466881,
#             "lon": 76.9304395,
#             "name": "Bangladesh Colony",
#             "place_id": "5106da1d528c3b534059603fc4060bef2040f00103f9010a76e39702000000c0020192031142616e676c616465736820436f6c6f6e79e203246f70656e7374726565746d61703a76656e75653a6e6f64652f3131313338323031303938",
#             "plus_code": "6JWRFW8J+Q5",
#             "plus_code_short": "FW8J+Q5 Thiruvananthapuram, India",
#             "postcode": "695001",
#             "rank": {
#                 "confidence": 0.9,
#                 "confidence_city_level": 0.9,
#                 "importance": 9.99999999995449e-06,
#                 "match_type": "inner_part",
#                 "popularity": 1.2268790831584977
#             },
#             "ref": "160A",
#             "result_type": "amenity",
#             "state": "Kerala",
#             "state_code": "KL",
#             "state_district": "Thiruvananthapuram District",
#             "street": "Thiruvananthapuram Bypass",
#             "suburb": "Thiruvallam",
#             "timezone": {
#                 "abbreviation_DST": "IST",
#                 "abbreviation_STD": "IST",
#                 "name": "Asia/Kolkata",
#                 "offset_DST": "+05:30",
#                 "offset_DST_seconds": 19800,
#                 "offset_STD": "+05:30",
#                 "offset_STD_seconds": 19800
#             }
#         },
#         {
#             "address_line1": "Viewpoint to Bangladesh",
#             "address_line2": "FOOTHPATH, - 793107, ML, India",
#             "bbox": {
#                 "lat1": 25.2243819,
#                 "lat2": 25.2244819,
#                 "lon1": 91.7283476,
#                 "lon2": 91.7284476
#             },
#             "category": "tourism.attraction.viewpoint",
#             "country": "India",
#             "country_code": "in",
#             "county": "Shella Bholaganj",
#             "datasource": {
#                 "attribution": "\u00a9 OpenStreetMap contributors",
#                 "license": "Open Database License",
#                 "sourcename": "openstreetmap",
#                 "url": "https://www.openstreetmap.org/copyright"
#             },
#             "formatted": "Viewpoint to Bangladesh, FOOTHPATH, - 793107, ML, India",
#             "lat": 25.2244319,
#             "lon": 91.7283976,
#             "name": "Viewpoint to Bangladesh",
#             "place_id": "51089ff7109eee564059dcad765e74393940f00103f90115038fac01000000c0020192031756696577706f696e7420746f2042616e676c6164657368e203236f70656e7374726565746d61703a76656e75653a6e6f64652f37313930303230383835",
#             "plus_code": "7MQH6PFH+Q9",
#             "postcode": "793107",
#             "rank": {
#                 "confidence": 0.81,
#                 "confidence_city_level": 0.81,
#                 "importance": 9.99999999995449e-06,
#                 "match_type": "inner_part",
#                 "popularity": 0.45710529876246103
#             },
#             "result_type": "amenity",
#             "state": "Meghalaya",
#             "state_code": "ML",
#             "state_district": "East Khasi Hills District",
#             "street": "FOOTHPATH",
#             "timezone": {
#                 "abbreviation_DST": "IST",
#                 "abbreviation_STD": "IST",
#                 "name": "Asia/Kolkata",
#                 "offset_DST": "+05:30",
#                 "offset_DST_seconds": 19800,
#                 "offset_STD": "+05:30",
#                 "offset_STD_seconds": 19800
#             }
#         },
#         {
#             "address_line1": "Bangladesh Plains Viewpoint",
#             "address_line2": "Sokhmi / Wah Lyngngam (The Green River) Trekking Route, Sohkhmi - 793110, ML, India",
#             "bbox": {
#                 "lat1": 25.2473861,
#                 "lat2": 25.2474861,
#                 "lon1": 91.7558702,
#                 "lon2": 91.7559702
#             },
#             "category": "tourism.attraction.viewpoint",
#             "city": "Sohkhmi",
#             "country": "India",
#             "country_code": "in",
#             "county": "Shella Bholaganj",
#             "datasource": {
#                 "attribution": "\u00a9 OpenStreetMap contributors",
#                 "license": "Open Database License",
#                 "sourcename": "openstreetmap",
#                 "url": "https://www.openstreetmap.org/copyright"
#             },
#             "formatted": "Bangladesh Plains Viewpoint, Sokhmi / Wah Lyngngam (The Green River) Trekking Route, Sohkhmi - 793110, ML, India",
#             "lat": 25.2474361,
#             "lon": 91.7559202,
#             "name": "Bangladesh Plains Viewpoint",
#             "place_id": "51b1581eff60f05640598c59e5f8573f3940f00103f901095f313f01000000c0020192031b42616e676c616465736820506c61696e732056696577706f696e74e203236f70656e7374726565746d61703a76656e75653a6e6f64652f35333535313637343937",
#             "plus_code": "7MQH6QW4+X9",
#             "postcode": "793110",
#             "rank": {
#                 "confidence": 0.81,
#                 "confidence_city_level": 0.81,
#                 "importance": 9.99999999995449e-06,
#                 "match_type": "inner_part",
#                 "popularity": 0.451039579706922
#             },
#             "result_type": "amenity",
#             "state": "Meghalaya",
#             "state_code": "ML",
#             "state_district": "East Khasi Hills District",
#             "street": "Sokhmi / Wah Lyngngam (The Green River) Trekking Route",
#             "timezone": {
#                 "abbreviation_DST": "IST",
#                 "abbreviation_STD": "IST",
#                 "name": "Asia/Kolkata",
#                 "offset_DST": "+05:30",
#                 "offset_DST_seconds": 19800,
#                 "offset_STD": "+05:30",
#                 "offset_STD_seconds": 19800
#             }
#         },
#         {
#             "address_line1": "Viewpoint over Bangladesh",
#             "address_line2": "FOOTHPATH, - 793107, ML, India",
#             "bbox": {
#                 "lat1": 25.2132072,
#                 "lat2": 25.2133072,
#                 "lon1": 91.7322488,
#                 "lon2": 91.7323488
#             },
#             "category": "tourism.attraction.viewpoint",
#             "country": "India",
#             "country_code": "in",
#             "county": "Shella Bholaganj",
#             "datasource": {
#                 "attribution": "\u00a9 OpenStreetMap contributors",
#                 "license": "Open Database License",
#                 "sourcename": "openstreetmap",
#                 "url": "https://www.openstreetmap.org/copyright"
#             },
#             "formatted": "Viewpoint over Bangladesh, FOOTHPATH, - 793107, ML, India",
#             "lat": 25.2132572,
#             "lon": 91.7322988,
#             "name": "Viewpoint over Bangladesh",
#             "place_id": "519a39c9fbddee564059f4a21b0698363940f00103f90178f299dc00000000c0020192031956696577706f696e74206f7665722042616e676c6164657368e203236f70656e7374726565746d61703a76656e75653a6e6f64652f33373031303736363030",
#             "plus_code": "7MQH6P7J+8W",
#             "postcode": "793107",
#             "rank": {
#                 "confidence": 0.81,
#                 "confidence_city_level": 0.81,
#                 "importance": 9.99999999995449e-06,
#                 "match_type": "inner_part",
#                 "popularity": 0.45710529876246103
#             },
#             "result_type": "amenity",
#             "state": "Meghalaya",
#             "state_code": "ML",
#             "state_district": "East Khasi Hills District",
#             "street": "FOOTHPATH",
#             "timezone": {
#                 "abbreviation_DST": "IST",
#                 "abbreviation_STD": "IST",
#                 "name": "Asia/Kolkata",
#                 "offset_DST": "+05:30",
#                 "offset_DST_seconds": 19800,
#                 "offset_STD": "+05:30",
#                 "offset_STD_seconds": 19800
#             }
#         },
#         {
#             "address_line1": "Deputy High Commission of Bangladesh",
#             "address_line2": "8, TL Wasvani Road, Zone 1, Mumbai - 400005, MH, India",
#             "bbox": {
#                 "lat1": 18.9158674,
#                 "lat2": 18.9159674,
#                 "lon1": 72.8178119,
#                 "lon2": 72.8179119
#             },
#             "city": "Mumbai",
#             "country": "India",
#             "country_code": "in",
#             "county": "Mumbai City",
#             "datasource": {
#                 "attribution": "\u00a9 OpenStreetMap contributors",
#                 "license": "Open Database License",
#                 "sourcename": "openstreetmap",
#                 "url": "https://www.openstreetmap.org/copyright"
#             },
#             "district": "Mumbai",
#             "formatted": "Deputy High Commission of Bangladesh, 8, TL Wasvani Road, Zone 1, Mumbai - 400005, MH, India",
#             "housenumber": "8",
#             "lat": 18.9159174,
#             "lon": 72.8178619,
#             "name": "Deputy High Commission of Bangladesh",
#             "neighbourhood": "Cuffe Parade",
#             "place_id": "513e4970d957345240595dd60e9079ea3240f00103f90156417a5c01000000c00201920324446570757479204869676820436f6d6d697373696f6e206f662042616e676c6164657368e203236f70656e7374726565746d61703a76656e75653a6e6f64652f35383436343833323836",
#             "plus_code": "7JCJWR89+94",
#             "plus_code_short": "WR89+94 Mumbai, Mumbai City, India",
#             "postcode": "400005",
#             "rank": {
#                 "confidence": 0.81,
#                 "confidence_city_level": 0.81,
#                 "importance": 9.99999999995449e-06,
#                 "match_type": "inner_part",
#                 "popularity": 2.367463450095889
#             },
#             "result_type": "amenity",
#             "state": "Maharashtra",
#             "state_code": "MH",
#             "street": "TL Wasvani Road",
#             "suburb": "Zone 1",
#             "timezone": {
#                 "abbreviation_DST": "IST",
#                 "abbreviation_STD": "IST",
#                 "name": "Asia/Kolkata",
#                 "offset_DST": "+05:30",
#                 "offset_DST_seconds": 19800,
#                 "offset_STD": "+05:30",
#                 "offset_STD_seconds": 19800
#             }
#         }
#     ]
# }

# %%
#Extract the Latitude and Longitude
lat = geo_data["results"][0]["lat"]
lon = geo_data["results"][0]["lon"]

#Print the result
print('''
    Country: {0}
    Latitude: {1}
    Longitude: {2}
    '''.format(target_city, lat, lon))
# Out:
#     Country: Bangladesh, India
#     Latitude: 8.466881
#     Longitude: 76.9304395

# %%
#Set the geographical coordinates for Bangladesh, India
latitude = 8.466881
longitude = 76.9304395

# Set the parameters to search for categories/conditions
categories = "healthcare.clinic_or_praxis.general"
radius = 8000

# Set the parameters for the type of search
filters = f"circle:{longitude},{latitude},{radius}"
bias = f"proximity:{longitude},{latitude}"
limit = 20

# Set up the parameters dictionary
params = {
    "categories":categories,
    "limit":limit,
    "filter":filters,
    "bias":bias,
    "apiKey":geoapify_key
}

# Create the base URL, and run a request using the params dictionary
base_url = "https://api.geoapify.com/v2/places"
response = requests.get(base_url, params=params)

# %%
# Print the response url
print(response.url)
# Out:
# https://api.geoapify.com/v2/places?categories=healthcare.clinic_or_praxis.general&limit=20&filter=circle%3A76.9304395%2C8.466881%2C8000&bias=proximity%3A76.9304395%2C8.466881&apiKey=1ced3e63f80a4286a6c314f9835cdc71

# %%
# Convert response to json and "pretty print" it
places_data = response.json()
print(json.dumps(places_data, indent=4, sort_keys=True))
# Out:
# {
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     76.93387561412636,
#                     8.479342199392441
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Government siddha hospita lVallakkadavu",
#                 "address_line2": "Vallakkadavu Road, Eanchakkal, Thiruvananthapuram - 695024, Kerala, India",
#                 "categories": [
#                     "healthcare",
#                     "healthcare.clinic_or_praxis.general",
#                     "healthcare.hospital"
#                 ],
#                 "city": "Thiruvananthapuram",
#                 "contact": {
#                     "phone": "+914712508807"
#                 },
#                 "country": "India",
#                 "country_code": "in",
#                 "county": "Thiruvananthapuram",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:postcode": 695024,
#                         "addr:street": "Vallakkadavu Road",
#                         "amenity": "hospital",
#                         "emergency": "yes",
#                         "healthcare": "alternative",
#                         "healthcare:speciality": "general",
#                         "name": "Government siddha hospita lVallakkadavu",
#                         "operator": "government",
#                         "operator:en": "Indian Systems of Medicine",
#                         "osm_id": 924852264,
#                         "osm_type": "w",
#                         "phone": "+914712508807",
#                         "ref": "010103320007"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact"
#                 ],
#                 "distance": 1413,
#                 "district": "V.V.Krishna Menon Nagar",
#                 "formatted": "Government siddha hospita lVallakkadavu, Vallakkadavu Road, Eanchakkal, Thiruvananthapuram - 695024, Kerala, India",
#                 "lat": 8.4793422,
#                 "lon": 76.93387561412638,
#                 "name": "Government siddha hospita lVallakkadavu",
#                 "operator": "government",
#                 "place_id": "51194d399ec43b5340596cf73b576cf52040f00102f9012820203700000000920327476f7665726e6d656e742073696464686120686f7370697461206c56616c6c616b6b6164617675",
#                 "postcode": "695024",
#                 "ref": "010103320007",
#                 "state": "Kerala",
#                 "state_code": "KL",
#                 "state_district": "Thiruvananthapuram District",
#                 "street": "Vallakkadavu Road",
#                 "suburb": "Eanchakkal"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     76.94907182172824,
#                     8.47603369939241
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Modern Health Centre",
#                 "address_line2": "Attukal Konchiravila Road, Manacaud, Thiruvananthapuram - 695009, Kerala, India",
#                 "categories": [
#                     "building",
#                     "building.healthcare",
#                     "healthcare",
#                     "healthcare.clinic_or_praxis",
#                     "healthcare.clinic_or_praxis.general"
#                 ],
#                 "city": "Thiruvananthapuram",
#                 "country": "India",
#                 "country_code": "in",
#                 "county": "Thiruvananthapuram",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Thiruvananthapuram",
#                         "addr:postcode": 695009,
#                         "addr:street": "Manacaud",
#                         "building": "yes",
#                         "healthcare": "clinic",
#                         "healthcare:speciality": "general",
#                         "name": "Modern Health Centre",
#                         "osm_id": 894462960,
#                         "osm_type": "w"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "distance": 2280,
#                 "district": "Pavithra Nagar",
#                 "formatted": "Modern Health Centre, Attukal Konchiravila Road, Manacaud, Thiruvananthapuram - 695009, Kerala, India",
#                 "lat": 8.476033699999999,
#                 "lon": 76.94907182172824,
#                 "name": "Modern Health Centre",
#                 "place_id": "5130f8bc97bd3c5340595c5e65b0baf32040f00102f901f06b5035000000009203144d6f6465726e204865616c74682043656e747265",
#                 "postcode": "695009",
#                 "state": "Kerala",
#                 "state_code": "KL",
#                 "state_district": "Thiruvananthapuram District",
#                 "street": "Attukal Konchiravila Road",
#                 "suburb": "Manacaud"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     76.95357686639004,
#                     8.464635699392291
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Government Ayurveda Dispensary, Kalady",
#                 "address_line2": "Panavila road, Kallattumukku, Thiruvananthapuram - 695001, Kerala, India",
#                 "categories": [
#                     "building",
#                     "building.healthcare",
#                     "healthcare",
#                     "healthcare.clinic_or_praxis.general"
#                 ],
#                 "city": "Thiruvananthapuram",
#                 "contact": {
#                     "phone": "+91-4712453430"
#                 },
#                 "country": "India",
#                 "country_code": "in",
#                 "county": "Thiruvananthapuram",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Thiruvananthapuram",
#                         "building": "yes",
#                         "healthcare": "alternative",
#                         "healthcare:speciality": "general",
#                         "is_in:district": "Thiruvananthapuram",
#                         "name": "Government Ayurveda Dispensary, Kalady",
#                         "operator": "Government",
#                         "operator:en": "Indian System of Medicine",
#                         "osm_id": 995520668,
#                         "osm_type": "w",
#                         "phone": "+91-4712453430",
#                         "ref": "010102320001"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact"
#                 ],
#                 "distance": 2556,
#                 "formatted": "Government Ayurveda Dispensary, Kalady, Panavila road, Kallattumukku, Thiruvananthapuram - 695001, Kerala, India",
#                 "lat": 8.4646357,
#                 "lon": 76.95357686639005,
#                 "name": "Government Ayurveda Dispensary, Kalady",
#                 "operator": "Government",
#                 "place_id": "5183d74367073d53405951e3fabae4ed2040f00102f9019c70563b00000000920326476f7665726e6d656e742041797572766564612044697370656e736172792c204b616c616479",
#                 "postcode": "695001",
#                 "ref": "010102320001",
#                 "state": "Kerala",
#                 "state_code": "KL",
#                 "state_district": "Thiruvananthapuram District",
#                 "street": "Panavila road",
#                 "suburb": "Kallattumukku"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     76.93096842255187,
#                     8.49497329939261
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Railway Hospital, Trivandrum",
#                 "address_line2": "Railway hospitl Road, Pettah, Thiruvananthapuram - 695024, Kerala, India",
#                 "categories": [
#                     "healthcare",
#                     "healthcare.clinic_or_praxis.general",
#                     "healthcare.hospital"
#                 ],
#                 "city": "Thiruvananthapuram",
#                 "country": "India",
#                 "country_code": "in",
#                 "county": "Thiruvananthapuram",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "trivandrum",
#                         "addr:postcode": 695024,
#                         "addr:street": "Railway hospitl Road",
#                         "amenity": "hospital",
#                         "healthcare": "hospital",
#                         "healthcare:speciality": "general",
#                         "name": "Railway Hospital, Trivandrum",
#                         "operator": "Southern Railways",
#                         "operator:type": "government",
#                         "osm_id": 1081587511,
#                         "osm_type": "w"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "distance": 3068,
#                 "formatted": "Railway Hospital, Trivandrum, Railway hospitl Road, Pettah, Thiruvananthapuram - 695024, Kerala, India",
#                 "lat": 8.494973300000002,
#                 "lon": 76.93096842255187,
#                 "name": "Railway Hospital, Trivandrum",
#                 "operator": "Southern Railways",
#                 "operator_details": {
#                     "type": "government"
#                 },
#                 "place_id": "51041e94fc943b534059a791ea236dfd2040f00102f90137b777400000000092031c5261696c77617920486f73706974616c2c2054726976616e6472756d",
#                 "postcode": "695024",
#                 "state": "Kerala",
#                 "state_code": "KL",
#                 "state_district": "Thiruvananthapuram District",
#                 "street": "Railway hospitl Road",
#                 "suburb": "Pettah"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     76.94844025,
#                     8.496637199392634
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Government Ayurveda Dispensary Secretariat",
#                 "address_line2": "Mahatma Gandhi Road, Pulimoodu, Thiruvananthapuram - 695001, Kerala, India",
#                 "categories": [
#                     "building",
#                     "building.healthcare",
#                     "healthcare",
#                     "healthcare.clinic_or_praxis.general"
#                 ],
#                 "city": "Thiruvananthapuram",
#                 "contact": {
#                     "phone": "+91-4712518976"
#                 },
#                 "country": "India",
#                 "country_code": "in",
#                 "county": "Thiruvananthapuram",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Thiruvananthapuram, Kerala",
#                         "addr:postcode": 695001,
#                         "building": "yes",
#                         "healthcare": "alternative",
#                         "healthcare:speciality": "general",
#                         "name": "Government Ayurveda Dispensary Secretariat",
#                         "operator": "Indian System Of Medicine",
#                         "operator:type": "government",
#                         "osm_id": 995208932,
#                         "osm_type": "w",
#                         "phone": "+91-4712518976",
#                         "ref": "010111320044"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact"
#                 ],
#                 "distance": 3840,
#                 "district": "Chenkalchoola Colony",
#                 "formatted": "Government Ayurveda Dispensary Secretariat, Mahatma Gandhi Road, Pulimoodu, Thiruvananthapuram - 695001, Kerala, India",
#                 "lat": 8.496637199999999,
#                 "lon": 76.94844025,
#                 "name": "Government Ayurveda Dispensary Secretariat",
#                 "operator": "Indian System Of Medicine",
#                 "operator_details": {
#                     "type": "government"
#                 },
#                 "place_id": "5172fdbb3eb33c5340599ebc223b47fe2040f00102f901e4ae513b0000000092032a476f7665726e6d656e742041797572766564612044697370656e73617279205365637265746172696174",
#                 "postcode": "695001",
#                 "ref": "010111320044",
#                 "state": "Kerala",
#                 "state_code": "KL",
#                 "state_district": "Thiruvananthapuram District",
#                 "street": "Mahatma Gandhi Road",
#                 "suburb": "Pulimoodu"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     76.90692548302647,
#                     8.511014349392788
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Ayurveda Dispensary Kadakampally",
#                 "address_line2": "Poonthi Road, Akkulam, Thiruvananthapuram - 695001, Kerala, India",
#                 "categories": [
#                     "building",
#                     "building.healthcare",
#                     "healthcare",
#                     "healthcare.clinic_or_praxis.general"
#                 ],
#                 "city": "Thiruvananthapuram",
#                 "country": "India",
#                 "country_code": "in",
#                 "county": "Thiruvananthapuram",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "building": "yes",
#                         "corporation": "Thiruvananthapuram",
#                         "healthcare": "alternative",
#                         "healthcare:speciality": "general",
#                         "name": "Ayurveda Dispensary Kadakampally",
#                         "operator": "Government",
#                         "operator:en": "Indian Systems Of Medicine",
#                         "osm_id": 1065774166,
#                         "osm_type": "w",
#                         "ref": "010102320005"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "distance": 5512,
#                 "district": "Venpalavattom",
#                 "formatted": "Ayurveda Dispensary Kadakampally, Poonthi Road, Akkulam, Thiruvananthapuram - 695001, Kerala, India",
#                 "lat": 8.51101435,
#                 "lon": 76.9069254830265,
#                 "name": "Ayurveda Dispensary Kadakampally",
#                 "operator": "Government",
#                 "place_id": "517e602e110b3a53405984db3caca3052140f00102f901566c863f0000000092032041797572766564612044697370656e73617279204b6164616b616d70616c6c79",
#                 "postcode": "695001",
#                 "ref": "010102320005",
#                 "state": "Kerala",
#                 "state_code": "KL",
#                 "state_district": "Thiruvananthapuram District",
#                 "street": "Poonthi Road",
#                 "suburb": "Akkulam"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     76.90670765,
#                     8.511264949392796
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Govt Ayurveda Dispensary Attipra",
#                 "address_line2": "Poonthi Road, Akkulam, Thiruvananthapuram - 695001, Kerala, India",
#                 "categories": [
#                     "building",
#                     "building.healthcare",
#                     "healthcare",
#                     "healthcare.clinic_or_praxis.general"
#                 ],
#                 "city": "Thiruvananthapuram",
#                 "contact": {
#                     "phone": "+91-4712412666"
#                 },
#                 "country": "India",
#                 "country_code": "in",
#                 "county": "Thiruvananthapuram",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Attipra",
#                         "building": "yes",
#                         "healthcare": "alternative",
#                         "healthcare:speciality": "general",
#                         "name": "Govt Ayurveda Dispensary Attipra",
#                         "operator": "Government",
#                         "operator:en": "Indian  Systems of Medicine",
#                         "osm_id": 828019469,
#                         "osm_type": "w",
#                         "phone": "+91-4712412666",
#                         "ref": "010105320019"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact"
#                 ],
#                 "distance": 5556,
#                 "district": "Venpalavattom",
#                 "formatted": "Govt Ayurveda Dispensary Attipra, Poonthi Road, Akkulam, Thiruvananthapuram - 695001, Kerala, India",
#                 "lat": 8.51126495,
#                 "lon": 76.90670765,
#                 "name": "Govt Ayurveda Dispensary Attipra",
#                 "operator": "Government",
#                 "place_id": "511df2857f073a5340596077fa84c4052140f00102f9010d935a3100000000920320476f76742041797572766564612044697370656e736172792041747469707261",
#                 "postcode": "695001",
#                 "ref": "010105320019",
#                 "state": "Kerala",
#                 "state_code": "KL",
#                 "state_district": "Thiruvananthapuram District",
#                 "street": "Poonthi Road",
#                 "suburb": "Akkulam"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     76.9826493,
#                     8.503210199392703
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Military Hospital",
#                 "address_line2": "Thiruvananthapuram-Neyyar Dam Road, Pangode, Thiruvananthapuram - 695006, Kerala, India",
#                 "categories": [
#                     "healthcare",
#                     "healthcare.clinic_or_praxis.general",
#                     "healthcare.hospital"
#                 ],
#                 "city": "Thiruvananthapuram",
#                 "country": "India",
#                 "country_code": "in",
#                 "county": "Thiruvananthapuram",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "thiruvananthapuram",
#                         "addr:postcode": 695006,
#                         "addr:street": "Pangode",
#                         "amenity": "hospital",
#                         "emergency": "yes",
#                         "healthcare": "hospital",
#                         "healthcare:speciality": "general",
#                         "name": "Military Hospital",
#                         "osm_id": 8461737304,
#                         "osm_type": "n"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [],
#                 "distance": 7014,
#                 "district": "MSP Nagar",
#                 "formatted": "Military Hospital, Thiruvananthapuram-Neyyar Dam Road, Pangode, Thiruvananthapuram - 695006, Kerala, India",
#                 "lat": 8.5032102,
#                 "lon": 76.9826493,
#                 "name": "Military Hospital",
#                 "place_id": "51fdbbe3b9e33e53405983cf6ac4a4012140f00103f90158dd5bf8010000009203114d696c697461727920486f73706974616c",
#                 "postcode": "695006",
#                 "state": "Kerala",
#                 "state_code": "KL",
#                 "state_district": "Thiruvananthapuram District",
#                 "street": "Thiruvananthapuram-Neyyar Dam Road",
#                 "suburb": "Pangode"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     76.91169790000001,
#                     8.53091194939302
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Government Ayurveda Dispensary, Ulloor",
#                 "address_line2": "Ulloor - Akkulam Road, Sreekariyam, Thiruvananthapuram - 695031, Kerala, India",
#                 "categories": [
#                     "building",
#                     "building.healthcare",
#                     "healthcare",
#                     "healthcare.clinic_or_praxis.general"
#                 ],
#                 "city": "Thiruvananthapuram",
#                 "country": "India",
#                 "country_code": "in",
#                 "county": "Thiruvananthapuram",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Thiruvananthapuram",
#                         "building": "yes",
#                         "healthcare": "alternative",
#                         "healthcare:speciality": "general",
#                         "is_in:district": "Thiruvananthapuram",
#                         "name": "Government Ayurveda Dispensary, Ulloor",
#                         "operator": "Government",
#                         "operator:en": "Indian System of Medicine",
#                         "osm_id": 995509487,
#                         "osm_type": "w",
#                         "ref": "010103320006"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "distance": 7375,
#                 "district": "Kallampally",
#                 "formatted": "Government Ayurveda Dispensary, Ulloor, Ulloor - Akkulam Road, Sreekariyam, Thiruvananthapuram - 695031, Kerala, India",
#                 "lat": 8.53091195,
#                 "lon": 76.91169790000001,
#                 "name": "Government Ayurveda Dispensary, Ulloor",
#                 "operator": "Government",
#                 "place_id": "513e152642593a534059b365e7b0d30f2140f00102f901ef44563b00000000920326476f7665726e6d656e742041797572766564612044697370656e736172792c20556c6c6f6f72",
#                 "postcode": "695031",
#                 "ref": "010103320006",
#                 "state": "Kerala",
#                 "state_code": "KL",
#                 "state_district": "Thiruvananthapuram District",
#                 "street": "Ulloor - Akkulam Road",
#                 "suburb": "Sreekariyam"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     76.98525818424736,
#                     8.427014699391929
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "primary health centre Vellayani",
#                 "address_line2": "College road, Thiruvananthapuram - 695001, Kerala, India",
#                 "categories": [
#                     "healthcare",
#                     "healthcare.clinic_or_praxis.general",
#                     "healthcare.hospital",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Thiruvananthapuram",
#                 "country": "India",
#                 "country_code": "in",
#                 "county": "Thiruvananthapuram",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "hospital",
#                         "healthcare": "hospital",
#                         "healthcare:speciality": "general",
#                         "name": "primary health centre Vellayani",
#                         "operator": "eHealth PMU",
#                         "operator:type": "government",
#                         "osm_id": 956297247,
#                         "osm_type": "w",
#                         "ref": 101,
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.facilities"
#                 ],
#                 "distance": 7468,
#                 "facilities": {
#                     "wheelchair": true
#                 },
#                 "formatted": "primary health centre Vellayani, College road, Thiruvananthapuram - 695001, Kerala, India",
#                 "lat": 8.4270147,
#                 "lon": 76.98525818424736,
#                 "name": "primary health centre Vellayani",
#                 "operator": "eHealth PMU",
#                 "operator_details": {
#                     "type": "government"
#                 },
#                 "place_id": "515cdd57780e3f5340596699b1aba1da2040f00102f9011ff0ff380000000092031f7072696d617279206865616c74682063656e7472652056656c6c6179616e69",
#                 "postcode": "695001",
#                 "ref": 101,
#                 "state": "Kerala",
#                 "state_code": "KL",
#                 "state_district": "Thiruvananthapuram District",
#                 "street": "College road"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     77.0000155,
#                     8.45837134939223
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Government Ayurveda Dispensary Nemom",
#                 "address_line2": "studio road, Nemom, Thiruvananthapuram - 695001, Kerala, India",
#                 "categories": [
#                     "building",
#                     "building.healthcare",
#                     "healthcare",
#                     "healthcare.clinic_or_praxis.general"
#                 ],
#                 "city": "Thiruvananthapuram",
#                 "country": "India",
#                 "country_code": "in",
#                 "county": "Thiruvananthapuram",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "building": "yes",
#                         "corporation": "Thiruvananthapuram",
#                         "healthcare": "alternative",
#                         "healthcare:speciality": "general",
#                         "name": "Government Ayurveda Dispensary Nemom",
#                         "operator": "Government",
#                         "operator:en": "Indian Systems Of Medicine",
#                         "osm_id": 1065815349,
#                         "osm_type": "w",
#                         "ref": "010102320003"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "distance": 7704,
#                 "formatted": "Government Ayurveda Dispensary Nemom, studio road, Nemom, Thiruvananthapuram - 695001, Kerala, India",
#                 "lat": 8.45837135,
#                 "lon": 77.0000155,
#                 "name": "Government Ayurveda Dispensary Nemom",
#                 "operator": "Government",
#                 "place_id": "518fff02410040534059442046a6afea2040f00102f901350d873f00000000920324476f7665726e6d656e742041797572766564612044697370656e73617279204e656d6f6d",
#                 "postcode": "695001",
#                 "ref": "010102320003",
#                 "state": "Kerala",
#                 "state_code": "KL",
#                 "state_district": "Thiruvananthapuram District",
#                 "street": "studio road",
#                 "suburb": "Nemom"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     76.9993389115758,
#                     8.484182799392494
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Government Ayureda Dispensary poojappura",
#                 "address_line2": "Thrikkannapuram-Kunnapuzha road, Thiruvananthapuram - 695001, Kerala, India",
#                 "categories": [
#                     "building",
#                     "building.healthcare",
#                     "healthcare",
#                     "healthcare.clinic_or_praxis.general"
#                 ],
#                 "city": "Thiruvananthapuram",
#                 "country": "India",
#                 "country_code": "in",
#                 "county": "Thiruvananthapuram",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "building": "yes",
#                         "healthcare": "alternative",
#                         "healthcare:speciality": "general",
#                         "is_in:district": "Thiruvananthapuram",
#                         "name": "Government Ayureda Dispensary poojappura",
#                         "operator": "Government",
#                         "operator:en": "Indian Systems Of Medicine",
#                         "osm_id": 1066012209,
#                         "osm_type": "w",
#                         "ref": "010102320004"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details"
#                 ],
#                 "distance": 7808,
#                 "formatted": "Government Ayureda Dispensary poojappura, Thrikkannapuram-Kunnapuzha road, Thiruvananthapuram - 695001, Kerala, India",
#                 "lat": 8.4841828,
#                 "lon": 76.9993389115758,
#                 "name": "Government Ayureda Dispensary poojappura",
#                 "operator": "Government",
#                 "place_id": "51a7b5312bf53f5340595d5ad1cee6f72040f00102f901310e8a3f00000000920328476f7665726e6d656e7420417975726564612044697370656e7361727920706f6f6a617070757261",
#                 "postcode": "695001",
#                 "ref": "010102320004",
#                 "state": "Kerala",
#                 "state_code": "KL",
#                 "state_district": "Thiruvananthapuram District",
#                 "street": "Thrikkannapuram-Kunnapuzha road"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     76.95461229999998,
#                     8.534729449393058
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Government Ayurveda Dispensary Chettivilakom",
#                 "address_line2": "Kuravankonam-Maruthoor Road, Paruthippara, Thiruvananthapuram - 695001, Kerala, India",
#                 "categories": [
#                     "building",
#                     "building.healthcare",
#                     "healthcare",
#                     "healthcare.clinic_or_praxis.general"
#                 ],
#                 "city": "Thiruvananthapuram",
#                 "contact": {
#                     "phone": "+91-4712430720"
#                 },
#                 "country": "India",
#                 "country_code": "in",
#                 "county": "Thiruvananthapuram",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "building": "yes",
#                         "corporation": "Thiruvananthapuram",
#                         "healthcare": "alternative",
#                         "healthcare:speciality": "general",
#                         "name": "Government Ayurveda Dispensary Chettivilakom",
#                         "operator": "Government",
#                         "operator:en": "Indian Systems Of Medicine",
#                         "osm_id": 1065055807,
#                         "osm_type": "w",
#                         "phone": "+91-4712430720",
#                         "ref": "010115320065"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact"
#                 ],
#                 "distance": 7953,
#                 "formatted": "Government Ayurveda Dispensary Chettivilakom, Kuravankonam-Maruthoor Road, Paruthippara, Thiruvananthapuram - 695001, Kerala, India",
#                 "lat": 8.53472945,
#                 "lon": 76.95461230000001,
#                 "name": "Government Ayurveda Dispensary Chettivilakom",
#                 "operator": "Government",
#                 "place_id": "51fe36305e183d534059dab3f20ec8112140f00102f9013f767b3f0000000092032c476f7665726e6d656e742041797572766564612044697370656e736172792043686574746976696c616b6f6d",
#                 "postcode": "695001",
#                 "ref": "010115320065",
#                 "state": "Kerala",
#                 "state_code": "KL",
#                 "state_district": "Thiruvananthapuram District",
#                 "street": "Kuravankonam-Maruthoor Road",
#                 "suburb": "Paruthippara"
#             },
#             "type": "Feature"
#         }
#     ],
#     "type": "FeatureCollection"
# }

# %%
# Print out the first hospital that appears to see if data is accurate
print(places_data["features"][0]["properties"]["name"])
print(places_data["features"][0]["properties"]["address_line2"])
print(places_data["features"][0]["geometry"]["coordinates"])
print(places_data["features"][0]["properties"]["distance"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 # Print out the first hospital that appears to see if data is accurate
# ----> 2 print(places_data["features"][0]["properties"]["name"])
#       3 print(places_data["features"][0]["properties"]["address_line2"])
#       4 print(places_data["features"][0]["geometry"]["coordinates"])
#
# NameError: name 'places_data' is not defined

# %%
# Print the results of the first 5 hospitals
counter = 0

for place in places_data["features"]:
    print(f"Hospital {counter+1}:")
    print(place["properties"]["name"])
    print(place["properties"]["address_line2"])
    print(place["geometry"]["coordinates"])
    print(place["properties"]["distance"])
    print("*"*20)
    
    counter = counter + 1
    if counter == 5:
        break

# %%
# Create hospital dataframe
coordinates = {
    "City": ["Kerala", "Kerala", "Kerala", "Kerala", "Kerala"],
    "Lat": [8.479342199392441, 8.47603369939241, 8.464635699392291, 8.49497329939261, 8.496637199392634],
    "Lon": [76.93387561412636, 76.94907182172824, 76.95357686639004, 76.93096842255187, 76.94844025],
    "Hospital Name": ["Government Siddha Hospital Vallakkadavu", "Modern Health Centre", "Government Ayurveda Dispensary", "Railway Hospital",
                     "Government Ayurveda Dispensary Secretariat"],
    "Hospital Address": ["Vallakkadavu Road, Eanchakkal, Thiruvananthapuram - 695024, India", "Attukal Konchiravila Road, Manacaud, Thiruvananthapuram - 695009, India",
                         "Panavila road, Kallattumukku, Thiruvananthapuram - 695001, India", "Railway hospital Road, Pettah, Thiruvananthapuram - 695024, India", 
                         "Mahatma Gandhi Road, Pulimoodu, Thiruvananthapuram - 695001, Kerala, India"],
    "Distance": [1413, 2280, 2556, 3068, 3840]
}

coordinates_df = pd.DataFrame(coordinates)
coordinates_df
# Out:
#      City       Lat        Lon                               Hospital Name  \
# 0  Kerala  8.479342  76.933876     Government Siddha Hospital Vallakkadavu
# 1  Kerala  8.476034  76.949072                        Modern Health Centre
# 2  Kerala  8.464636  76.953577              Government Ayurveda Dispensary
# 3  Kerala  8.494973  76.930968                            Railway Hospital
# 4  Kerala  8.496637  76.948440  Government Ayurveda Dispensary Secretariat
#
#                                     Hospital Address  Distance
# 0  Vallakkadavu Road, Eanchakkal, Thiruvananthapu...      1413
# 1  Attukal Konchiravila Road, Manacaud, Thiruvana...      2280
# 2  Panavila road, Kallattumukku, Thiruvananthapur...      2556
# 3  Railway hospital Road, Pettah, Thiruvananthapu...      3068
# 4  Mahatma Gandhi Road, Pulimoodu, Thiruvananthap...      3840

# %%
# Configure the map
map_plot_1 = coordinates_df.hvplot.points(
    "Lon",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Distance",
    scale = 0.2,
    color = "Hospital Name"
)

# Display the map plot
map_plot_1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lon,Lat]   (Hospital Name,Distance)
